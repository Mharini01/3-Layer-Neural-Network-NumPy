# %%
import numpy as np

# -----------------------------
# XOR Dataset
# -----------------------------
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([
    [0],
    [1],
    [1],
    [0]
])

# -----------------------------
# Initialize Weights and Biases
# -----------------------------
np.random.seed(42)

W1 = np.random.rand(2, 4)      # Input -> Hidden
b1 = np.zeros((1, 4))

W2 = np.random.rand(4, 1)      # Hidden -> Output
b2 = np.zeros((1, 1))

# -----------------------------
# Sigmoid Function
# -----------------------------
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# -----------------------------
# Sigmoid Derivative
# -----------------------------
def sigmoid_derivative(x):
    return x * (1 - x)

# -----------------------------
# Training
# -----------------------------
learning_rate = 0.5
epochs = 50000

for epoch in range(epochs):

    # Forward Propagation
    hidden = sigmoid(np.dot(X, W1) + b1)
    output = sigmoid(np.dot(hidden, W2) + b2)

    # Loss (Mean Squared Error)
    loss = np.mean((y - output) ** 2)

    # Backpropagation
    output_error = y - output
    output_delta = output_error * sigmoid_derivative(output)

    hidden_error = np.dot(output_delta, W2.T)
    hidden_delta = hidden_error * sigmoid_derivative(hidden)

    # Update Weights and Biases
    W2 += learning_rate * np.dot(hidden.T, output_delta)
    b2 += learning_rate * np.sum(output_delta, axis=0, keepdims=True)

    W1 += learning_rate * np.dot(X.T, hidden_delta)
    b1 += learning_rate * np.sum(hidden_delta, axis=0, keepdims=True)

    # Print loss every 5000 epochs
    if epoch % 5000 == 0:
        print(f"Epoch {epoch}, Loss = {loss:.6f}")

# -----------------------------
# Final Predictions
# -----------------------------
print("\nFinal Predictions:")
print(output)

print("\nRounded Predictions:")
print((output > 0.5).astype(int))
# Out:
# Epoch 0, Loss = 0.341657
# Epoch 5000, Loss = 0.000646
# Epoch 10000, Loss = 0.000272
# Epoch 15000, Loss = 0.000170
# Epoch 20000, Loss = 0.000123
# Epoch 25000, Loss = 0.000096
# Epoch 30000, Loss = 0.000078
# Epoch 35000, Loss = 0.000066
# Epoch 40000, Loss = 0.000057
# Epoch 45000, Loss = 0.000050
#
# Final Predictions:
# [[0.00791503]
#  [0.99365018]
#  [0.99370173]
#  [0.00608312]]
#
# Rounded Predictions:
# [[0]
#  [1]
#  [1]
#  [0]]
